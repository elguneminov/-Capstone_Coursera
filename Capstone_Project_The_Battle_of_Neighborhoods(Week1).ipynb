# %% [markdown]
# **Capstone Project -- The Battle of Neighborhoods**

# %% [markdown]
# **Introduction : Bussiness Problem**

# %% [markdown]
# In this project we will try to find the optimal location for a resturant . Specifically , this will be helpful for stakeholder who are going to open new Italian Resturant in the Kormangla area of Banglore, India
#
# Since there are many resturants in the banglore , we will try to find the area where  there are less crowd. And We will also prefer that it wil be close to the city center
#
# We Will use ML algorithm to generate most promising neighbourhood.

# %% [markdown]
# **Data Extarction**
#
# The list of factors which will influence our decisions are:
# *   Number of existing resturants in the neighbourhood.
# *   Number of italina resturant
# *   Distance of the neighbor from the city

# %% [markdown]
# **Neighbor Candidates**
# We will create a grid of cells covering area of interest which is approx 12x12 KM centerd arounf Banglore center.

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.6/dist-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.6/dist-packages (from geopy) (1.50)

# %%
import ssl
import sys
import certifi
import geopy.geocoders
ctx = ssl.create_default_context(cafile=certifi.where())
geopy.geocoders.options.default_ssl_context = ctx
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="banglore_loc")
location = geolocator.geocode("Bangalore")

# %%
print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
bang_lat,bang_long = location.latitude, location.longitude
# Out:
# Latitude = 12.9791198, Longitude = 77.5912997

# %% [markdown]
# As we have find the latitude and longitude of the area , equally spaced , centered around city  and within 6Km from Banglore. We will distribute the neighbour of 300 m so that the distance will be 600m between two neighbour.

# %%
# !pip install shapely
# !pip install pyproj
# Out:
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (1.7.0)
# Collecting pyproj
#   Downloading https://files.pythonhosted.org/packages/d6/70/eedc98cd52b86de24a1589c762612a98bea26cde649ffdd60c1db396cce8/pyproj-2.4.2.post1-cp36-cp36m-manylinux2010_x86_64.whl (10.1MB)
#      |████████████████████████████████| 10.1MB 4.7MB/s
# Installing collected packages: pyproj
# Successfully installed pyproj-2.4.2.post1

# %% [markdown]
# We have to convert the data into 2D cartesian .We need the coordinate in X,Y cordinate because we are planning to make a hexagonal frid of the area,

# %%
import shapely.geometry
import pyproj
import math

#For converion in 2D
def longlot_to_xy(lon,lat):
  proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
  proj_xy = pyproj.Proj(proj='utm',zone=33,datum='WGS84')
  xy = pyproj.transform(proj_latlon,proj_xy,lon,lat)
  return xy[0],xy[1]


#Vice-versa
def xy_to_langlot(x,y):
  proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
  proj_xy = pyproj.Proj(proj='utm',zone=33,datum='WGS84')
  lonlat = pyproj.transform(proj_xy,proj_latlon,x,y)
  return lonlat[0],lonlat[1]

# To find the distance between two neighbours
def calc_xy_distance(x1,y1,x2,y2):
  dx = x2-x1
  dy = y2-y1
  return math.sqrt(dx*dx+dy*dy)

#For checking purpose
print('Banglore centre latitude={}, longitude={}'.format(bang_lat,bang_long))
x,y = longlot_to_xy(bang_lat,bang_long)
print('Banglore center UTM x={}, y={}'.format(x,y))
lon,lat = xy_to_langlot(x,y)
print('Banglore centre latitude={}, longitude={}'.format(lat,lon))
# Out:
# Banglore centre latitude=12.9791198, longitude=77.5912997
# Banglore center UTM x=451532.50057396025, y=8613593.967979895
# Banglore centre latitude=77.5912997, longitude=12.9791198

# %% [markdown]
# **Now lets create hexagoanl grid such that it is equally distant from each other**

# %%
#Here we will store the lat and longitude of the all the hexagonal grid
bang_cen_x,bang_cen_y = longlot_to_xy(bang_long,bang_lat)#In Cartesian form

k = math.sqrt(3)/2 # Vertical offset for horizonal grid
x_min = bang_cen_x - 6000 # since we are covering 6 Km
x_step = 600
y_min = bang_cen_y - 6000- (int(21/k)*k*600-12000)/2
y_step = 600*k

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
for i in range(0, int(21/k)):
    y = y_min + i * y_step
    x_offset = 300 if i%2==0 else 0
    for j in range(0, 21):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(bang_cen_x, bang_cen_y, x, y)
        if (distance_from_center <= 6001):
            lon, lat = xy_to_langlot(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)

print(len(latitudes), 'candidate neighborhood centers generated.')
# Out:
# 364 candidate neighborhood centers generated.

# %%
# Vizualization
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.21.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from folium) (1.17.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.11.1)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium) (0.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.12.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.1.1)

# %%
import folium

# %%
map_bang = folium.Map(location = [bang_lat,bang_long],zoom_start =12)
folium.Marker([bang_lat,bang_long],popup='Banglore').add_to(map_bang)
for lat,lon in zip(latitudes,longitudes):#latitudes and longitudes of the hexagon defined in the above part
  folium.Circle([lat,lon],radius=10,color='blue',fill=False).add_to(map_bang)
map_bang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ctx = ssl.create_default_context(cafile=certifi.where())
geopy.geocoders.options.default_ssl_context = ctx
geolocator = Nominatim(user_agent="bang_address")
def get_address(latitudes,longitudes):
  location = geolocator.reverse([latitudes,longitudes])
  return location.address

addrr = get_address(12.958820695085988,77.57312796930427)  
print('The address is {}'.format(addrr))
# Out:
# The address is Fort High School, Krishna Rajendra Road, Mavalli, Vishveshwara Puram, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002, India

# %%
 pip install python-googlegeocoder
# Out:
# Collecting python-googlegeocoder
#   Downloading https://files.pythonhosted.org/packages/bf/3c/56f36a5e2e1e0294eafa3f563d2d71d028ae8f79348e585df36a323706ab/python_googlegeocoder-0.4.0-py3-none-any.whl
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from python-googlegeocoder) (1.12.0)
# Installing collected packages: python-googlegeocoder
# Successfully installed python-googlegeocoder-0.4.0

# %% [markdown]
# We are using only 60 records because of computation problem

# %%
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes[0:60], longitudes[0:60]):
    address = get_address(lat,lon)
    if address is None:
         address = 'NO ADDRESS'
    address = address.replace(', India', '') # We don't need country part of address
    addresses.append(address)
    print(' .', end='')
for lat, lon in zip(latitudes[61:120], longitudes[61:120]):
    address = get_address(lat,lon)
    if address is None:
         address = 'NO ADDRESS'
    address = address.replace(', India','') # We don't need country part of address
    addresses.append(address) 
    print(' .', end='')   
for lat, lon in zip(latitudes[121:160], longitudes[121:160]):
    address = get_address(lat,lon)
    if address is None:
         address = 'NO ADDRESS'
    address = address.replace(', India','') # We don't need country part of address
    addresses.append(address) 
    print(' .', end='')       
print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
addresses[50:150]
# Out:
# ['ರಾಜಣ್ಣ ಲೇನ್, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Dasappa Maternity Hospital, Pehalwan Krishnappa Road, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560002',
#  "Bishop Cotton's Women's Christian College, 19, 3rd Cross Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027",
#  'Government Pharmacy College, Kalinga Rao Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027',
#  'Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027',
#  'Utsav, Shanti Road, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 650027',
#  'Leprosy Hospital, Tank Bund Road, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Cottonpete Main Road, Ranasingpete, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002',
#  'Sultanpete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Sultanpete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Mamulpete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Raghavendra market, Avenue Road, Mamulpete, Chickpete, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'ಮಕ್ಕಳ ಬಸವಣ್ಣ ದೇವಸ್ಥಾನ ರಸ್ತೆ, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Chikka Anamma Temple, C.A.T Street, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Karnatak State Tourism Development Corporation - KSTDC, Proposed Hudson Cricle - Minerva Circle Flyover, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002',
#  'Mitralaya Girls College, ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560002',
#  'BSNL Telephone Exchange, Chidananda Maharashi Ashram Road, Sampangi Rama Nagara, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Surya Bakery, Kalinga Rao Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Moyenville Road, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Nephrolife Care India Pvt.Ltd, Setlur Street, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025',
#  'Hosur Road, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025',
#  'Prestige West Woods, Okalipuram Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560023',
#  "Sr Section Engineer Bridge's Railway, Tank Bund Road, Bangalore City Junction, Subhash Nagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053",
#  'Platform 2,3, Cottonpete Main Road, Ranasingpete, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002',
#  'KSRTC Terminal 3, Tank Bund Road, Railway Colony, Subhash Nagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Balepet, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Mamulpete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'ಸಂಜೀವಪ್ಪ ಗಲ್ಲಿ, Mamulpete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  '೧೩ನೇ ಅಡ್ಡ ರಸ್ತೆ, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Proposed Hudson Cricle - Minerva Circle Flyover, Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Karnataka Arts & Crafts Emporium, Devanga Hostel Road, Sampangirama Nagar, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'ಮುನಿಸ್ವಮಪ್ಪ ರಸ್ತೆ, Sampangi Rama Nagara, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  '11th Cross, Sampangi Rama Nagara, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'New Upidi Upahar, Mission Road, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'CHF International, Cornwell Road, MacIvor Town, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"',
#  'Hockey Stadium, Prime Street, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025',
#  'Wellington Street, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025',
#  'Hosur Road, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025',
#  'Mother Teresa Road, Vannarpete Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, - 560095',
#  'Railway Colony, Subhash Nagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 020',
#  'Platform 5,6, Cottonpete Main Road, Ranasingpete, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002',
#  'City Bus Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Kempegowda KSRTC Bus Station, 1st Cross Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Anand Sagar Punjabi Dhaba, Subedar Chatram Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Pothys, Kalidasa Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Palace Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'Karnataka Housing Board, District Office Road, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053',
#  'St Marthas Hospital, ೧೦ನೇ ಅಡ್ಡ ರಸ್ತೆ, Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'YMCA, Nrupathunga Road, Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'Sree Kanteerava Stadium, Rajaram Mohan Roy Road, Sampangirama Nagar, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001PH',
#  'Sree Kanteerava Stadium, Rajaram Mohan Roy Road, Sampangirama Nagar, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001PH',
#  'ITC Gardenia Royal, 1, Field Marshal Cariappa Road, MacIvor Town, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025',
#  'Chancery Pavilion, Field Marshal Cariappa Road, MacIvor Town, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025',
#  'MacIvor Town, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025',
#  'Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025',
#  'Baldwin Boys High School, Serpentine Street, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025',
#  'Hosur Road, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025',
#  'Okalipuram Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 020',
#  'Kendriya Vidyalaya, 5th Cross Road, Okalipuram Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 020',
#  'Bangalore City Junction, Subhash Nagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Government Ayurvedic Medical College, Sheshadri Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Jayant Probikes & Fitness, 7, 2nd Cross Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Central College, Post Office Road, Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'University Visvesvaraya College of Engineering - UVCE, Nrupathunga Road, Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'Reserve Bank of India, Nrupathunga Road, Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'BWSSB Treatment Plant, Kasturba Road, Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'Sree Kanteerava Stadium, Rajaram Mohan Roy Road, Sampangirama Nagar, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001PH',
#  'Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001PH',
#  "Bishop Cotton's Boys High School, Saint Mark's Road, MacIvor Town, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025",
#  'B2, Hayes Road, MacIvor Town, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  "Cafe Mor'ish, Richmond Road Cycle Path, MacIvor Town, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025",
#  'St Gregorios Orthodox Cathedral, Arab Lane B street, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025',
#  'Cathedral High School & College, Campbell Road, Xavier Layout, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025',
#  'Rashtriya Military School, Mother Teresa Road, Yellagondanpalya, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, - 560095',
#  'Okalipuram Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 020',
#  'Kranthikavi Sarvagnya Road, Railway Colony, Subhash Nagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 020',
#  'Gethsemane Church, Platform Road, Railway Colony, Subhash Nagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 020',
#  'Dhanvanthari Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 020',
#  'Axis Bank, Sheshadri Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Café Coffee Day, Sheshadri Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Maha Bodhi Society, 14, Kalidasa Road, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Smt V.H.D Central Institute of Home Science College, ರಾಮಚಂದ್ರ ರಸ್ತೆ, Gandhinagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560009',
#  'Central College, Post Office Road, Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'State Central Library, Doctor B R Ambedkar Veedhi, Cubbonpet, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, - 560051',
#  'Sampangirama Nagar, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'Farzi Cafe, Vittal Mallya Road, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001PH',
#  'O2 Spa, No.5, Vittal Mallya Road, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560001',
#  'Bank of India, Saint Marks Road Cycle Path, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025',
#  'Sacred Hearts Nursery School, Convent Road, MacIvor Town, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 025',
#  'Indiahomes, No.57/1,, ಆಲ್ಬರ್ಟ್ ರಸ್ತೆ, MacIvor Town, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560046',
#  'Bamburies, Richmond Road Cycle Path, Xavier Layout, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025',
#  'St. Philomenas Hospital - Bangalore, 4, Anjaneya Temple Street, Xavier Layout, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560047']

# %%
import pandas as pd

df_locations = pd.DataFrame({'Address': addresses[0:155],
                             'Latitude': latitudes[0:155],
                             'Longitude': longitudes[0:155],
                             'X': xs[0:155],
                             'Y': ys[0:155],
                             'Distance from center': distances_from_center[0:155]})

df_locations.head(10)
# Out:
#                                              Address  ...  Distance from center
# 0  Fort High School, Krishna Rajendra Road, Maval...  ...           5992.495307
# 1  Dharmaraya Swamy Temple Ward, South Zone, Beng...  ...           5840.376700
# 2  Dharmaraya Swamy Temple Ward, South Zone, Beng...  ...           5747.173218
# 3  Hindustan Petroleum, Proposed Hudson Cricle - ...  ...           5715.767665
# 4  New car designer, Lalbagh Fort Road, Mavalli, ...  ...           5747.173218
# 5  Lalbagh Botanical Gardens, ಪಾದಚಾರಿ ಮಾರ್ಗ, Mava...  ...           5840.376700
# 6  Lalbagh Botanical Gardens, ಪಾದಚಾರಿ ಮಾರ್ಗ, Mava...  ...           5992.495307
# 7  St. Joseph's School, Cottonpete Main Road, K R...  ...           5855.766389
# 8  Bangalore Medical College Hospitals, ಸುಲ್ತಾನ್ ...  ...           5604.462508
# 9  Srinidhi Sagar, 2, Krishna Rajendra Road, K R ...  ...           5408.326913
#
# [10 rows x 6 columns]

# %%
df_locations.to_pickle('./locations.pkl')

# %%
client_id = 'WQKMV45IUJFHR204GLPOFWAO4AWDFRTMISHNLDRHOLKD2FO4'
client_secret = 'UWBSPVL1GOZO1OLP3JYWNOBH2CDQ545L13MK5LJBGANSZ4SF'
version = '20180604'

# %%
import requests 
limit =100
def getNearbyVenues(names, latitudes, longitudes, radius=300):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            client_id, 
            client_secret, 
            version, 
            lat, 
            lng, 
            radius, 
            limit)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df_locations['Address'],
                                   latitudes=df_locations['Latitude'],
                                   longitudes=df_locations['Longitude'],
                                  )
# Out:
# Fort High School, Krishna Rajendra Road, Mavalli, Vishveshwara Puram, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Hindustan Petroleum, Proposed Hudson Cricle - Minerva Circle Flyover, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# New car designer, Lalbagh Fort Road, Mavalli, Vishveshwara Puram, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Lalbagh Botanical Gardens, ಪಾದಚಾರಿ ಮಾರ್ಗ, Mavalli, Vishveshwara Puram, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka
# Lalbagh Botanical Gardens, ಪಾದಚಾರಿ ಮಾರ್ಗ, Mavalli, Vishveshwara Puram, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka
# St. Joseph's School, Cottonpete Main Road, K R Market Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Bangalore Medical College Hospitals, ಸುಲ್ತಾನ್ ರಸ್ತೆ, K R Market Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Srinidhi Sagar, 2, Krishna Rajendra Road, K R Market Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560008
# Kalasipalya Main Road, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Malvalli Tank Bund Road, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Popular Traders, H Siddaiah Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Urvashi, Lalbagh Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Bada Makan, H. Siddiah Road, Hombegowda Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Family & Labour Courts, 6/69, H. Siddiah Road, Hombegowda Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Siddaiah Road, Hombegowda Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 650027
# Chalavadipalya Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Cottonpete Main Road, K R Market Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Bangalore Medical College Hospitals, ಸುಲ್ತಾನ್ ರಸ್ತೆ, K R Market Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Bangalore Medical College Hospitals, ಸುಲ್ತಾನ್ ರಸ್ತೆ, K R Market Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Kalasipalya Main Road, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# 3rd Cross Road, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Kumbaragundi Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# National High School Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Hombegowda Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Hombegowda Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# BTS Main Road, Hombegowda Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# BMTC Bus Depot Road, Hombegowda Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Gajendra Nagara, Shanthi Nagar, East Zone, Bengaluru, Bangalore South, Bangalore Urban, Karnataka, 650027
# Belli Mutt Road, Ranasingpete, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Super talkies, Belli Mutt Road, Ranasingpete, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# K R Market Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# K R Market Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Dargah, Avenue Road, Mamulpete, Chickpete, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Bala Gangadhara Swamy Flyover, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# New Mission Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Lalbagh Cross Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore South, Bangalore Urban, Karnataka, 650027
# Tank Bund Road, Bangalore City Junction, Subhash Nagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Ranasingpete, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Ranasingpete, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Sultanpete Main Road, Sultanpete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Prince Sports India, 307, ಹಳೆ ತರಗುಪೇಟೆ ರಸ್ತೆ, Old Tharagupete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# ರಾಜಣ್ಣ ಲೇನ್, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Dasappa Maternity Hospital, Pehalwan Krishnappa Road, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560002
# Bishop Cotton's Women's Christian College, 19, 3rd Cross Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Government Pharmacy College, Kalinga Rao Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027
# Utsav, Shanti Road, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"
# Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"
# Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"
# Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 650027
# Leprosy Hospital, Tank Bund Road, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Cottonpete Main Road, Ranasingpete, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Sultanpete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Sultanpete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Mamulpete, Chickpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Raghavendra market, Avenue Road, Mamulpete, Chickpete, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# ಮಕ್ಕಳ ಬಸವಣ್ಣ ದೇವಸ್ಥಾನ ರಸ್ತೆ, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Chikka Anamma Temple, C.A.T Street, Ganigarpet, Dharmaraya Swamy Temple Ward, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Karnatak State Tourism Development Corporation - KSTDC, Proposed Hudson Cricle - Minerva Circle Flyover, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# Mitralaya Girls College, ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560002
# BSNL Telephone Exchange, Chidananda Maharashi Ashram Road, Sampangi Rama Nagara, Sampangiram Nagar Ward, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"
# Surya Bakery, Kalinga Rao Road, Sudhama Nagara, South Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"
# Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"
# Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"
# Moyenville Road, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560027"
# Nephrolife Care India Pvt.Ltd, Setlur Street, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025
# Hosur Road, Richmond Town, Shanthi Nagar, East Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560025
# Prestige West Woods, Okalipuram Ward, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560023
# Sr Section Engineer Bridge's Railway, Tank Bund Road, Bangalore City Junction, Subhash Nagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# Platform 2,3, Cottonpete Main Road, Ranasingpete, Cottonpete, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560 002
# KSRTC Terminal 3, Tank Bund Road, Railway Colony, Subhash Nagar, West Zone, Bengaluru, Bangalore North, Bangalore Urban, Karnataka, 560053
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-9f34dc83133c> in <module>()
#       1 toronto_venues = getNearbyVenues(names=df_locations['Address'],
#       2                                    latitudes=df_locations['Latitude'],
# ----> 3                                    longitudes=df_locations['Longitude'],
#       4                                   )
#
# <ipython-input-43-1f9dfd627c51> in getNearbyVenues(names, latitudes, longitudes, radius)
#      18
#      19         # make the GET request
# ---> 20         results = requests.get(url).json()["response"]['groups'][0]['items']
#      21
#      22         # return only relevant information for each nearby venue
#
# KeyError: 'groups'

# %%
food_category = '4d4b7105d754a06374d81259'

italian_restaurant_categories = ['4bf58dd8d48988d110941735','55a5a1ebe4b013909087cbb6','55a5a1ebe4b013909087cb7c',
                                 '55a5a1ebe4b013909087cba7','55a5a1ebe4b013909087cba1','55a5a1ebe4b013909087cba4',
                                 '55a5a1ebe4b013909087cb95','55a5a1ebe4b013909087cb89','55a5a1ebe4b013909087cb9b',
                                 '55a5a1ebe4b013909087cb98','55a5a1ebe4b013909087cbbf','55a5a1ebe4b013909087cb79',
                                 '55a5a1ebe4b013909087cbb0','55a5a1ebe4b013909087cbb3','55a5a1ebe4b013909087cb74',
                                 '55a5a1ebe4b013909087cbaa','55a5a1ebe4b013909087cb83','55a5a1ebe4b013909087cb8c',
                                 '55a5a1ebe4b013909087cb92','55a5a1ebe4b013909087cb8f','55a5a1ebe4b013909087cb86',
                                 '55a5a1ebe4b013909087cbb9','55a5a1ebe4b013909087cb7f','55a5a1ebe4b013909087cbbc',
                                 '55a5a1ebe4b013909087cb9e','55a5a1ebe4b013909087cbc2','55a5a1ebe4b013909087cbad']

# %%
def is_restaurant(categories, specific_filter=None):
    restaurant_words = ['restaurant', 'hotel', 'dining', 'bites']
    restaurant = False
    specific = False
    for c in categories:
        category_name = c[0].lower()
        category_id = c[1]
        for r in restaurant_words:
            if r in category_name:
                restaurant = True
        if 'fast food' in category_name:
            restaurant = False
        if not(specific_filter is None) and (category_id in specific_filter):
            specific = True
            restaurant = True
    return restaurant, specific

def get_categories(categories):
    return [(cat['name'], cat['id']) for cat in categories]

def format_address(location):
    address = ', '.join(location['formattedAddress'])
    address = address.replace(', Deutschland', '')
    address = address.replace(', Germany', '')
    return address

def get_venues_near_location(lat, lon, category, client_id, client_secret, radius=500, limit=100):
    version = '20180724'
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
        client_id, client_secret, version, lat, lon, category, radius, limit)
    try:
        results = requests.get(url).json()['response']['groups'][0]['items']
        venues = [(item['venue']['id'],
                   item['venue']['name'],
                   get_categories(item['venue']['categories']),
                   (item['venue']['location']['lat'], item['venue']['location']['lng']),
                   format_address(item['venue']['location']),
                   item['venue']['location']['distance']) for item in results]        
    except:
        venues = []
    return venues

# %%
# Let's now go over our neighborhood locations and get nearby restaurants; we'll also maintain a dictionary of all found restaurants and all found italian restaurants

import pickle

def get_restaurants(lats, lons):
    restaurants = {}
    italian_restaurants = {}
    location_restaurants = []

    print('Obtaining venues around candidate locations:', end='')
    for lat, lon in zip(lats, lons):
        # Using radius=350 to meke sure we have overlaps/full coverage so we don't miss any restaurant (we're using dictionaries to remove any duplicates resulting from area overlaps)
        venues = get_venues_near_location(lat, lon, food_category, client_id, client_secret, radius=350, limit=100)
        area_restaurants = []
        for venue in venues:
            venue_id = venue[0]
            venue_name = venue[1]
            venue_categories = venue[2]
            venue_latlon = venue[3]
            venue_address = venue[4]
            venue_distance = venue[5]
            is_res, is_italian = is_restaurant(venue_categories, specific_filter=italian_restaurant_categories)
            if is_res:
                x, y = longlot_to_xy(venue_latlon[1], venue_latlon[0])
                restaurant = (venue_id, venue_name, venue_latlon[0], venue_latlon[1], venue_address, venue_distance, is_italian, x, y)
                if venue_distance<=300:
                    area_restaurants.append(restaurant)
                restaurants[venue_id] = restaurant
                if is_italian:
                    italian_restaurants[venue_id] = restaurant
        location_restaurants.append(area_restaurants)
        print(' .', end='')
    print(' done.')
    return restaurants, italian_restaurants, location_restaurants

# Try to load from local file system in case we did this before
restaurants = {}
italian_restaurants = {}
location_restaurants = []
loaded = False
try:
    with open('restaurants_350.pkl', 'rb') as f:
        restaurants = pickle.load(f)
    with open('italian_restaurants_350.pkl', 'rb') as f:
        italian_restaurants = pickle.load(f)
    with open('location_restaurants_350.pkl', 'rb') as f:
        location_restaurants = pickle.load(f)
    print('Restaurant data loaded.')
    loaded = True
except:
    pass

# If load failed use the Foursquare API to get the data
if not loaded:
    restaurants, italian_restaurants, location_restaurants = get_restaurants(latitudes, longitudes)
    
    # Let's persists this in local file system
    with open('restaurants_351.pkl', 'wb') as f:
        pickle.dump(restaurants, f)
    with open('italian_restaurants_351.pkl', 'wb') as f:
        pickle.dump(italian_restaurants, f)
    with open('location_restaurants_351.pkl', 'wb') as f:
        pickle.dump(location_restaurants, f)
# Out:
# Restaurant data loaded.

# %%
import numpy as np

print('Total number of restaurants:', len(restaurants))
print('Total number of Italian restaurants:', len(italian_restaurants))
print('Percentage of Italian restaurants: {:.2f}%'.format(len(italian_restaurants) / len(restaurants) * 100))
print('Average number of restaurants in neighborhood:', np.array([len(r) for r in location_restaurants]).mean())
# Out:
# Total number of restaurants: 461
# Total number of Italian restaurants: 14
# Percentage of Italian restaurants: 3.04%
# Average number of restaurants in neighborhood: 3.489010989010989

# %%
print('List of all restaurants')
print('-----------------------')
for r in list(restaurants.values())[:10]:
    print(r)
print('...')
print('Total:', len(restaurants))
# Out:
# List of all restaurants
# -----------------------
# ('4f093e86e4b0ef60ee6d3df4', 'Prakash cafe', 12.96049019646807, 77.57102892400674, 'India', 225, False, 8884988.517896798, 2961995.196752784)
# ('524d2f9f8bbd97b6e12fecd9', 'Classic Caterers', 12.957893430072096, 77.57694661617279, 'No.13/11 A M Road,Kalasipalyam, Bangalore 560002, Karnātaka, India', 330, False, 8886398.906232743, 2961987.157351209)
# ('4f7a853ae4b0d859b60c9715', 'BIT Canteen', 12.95481286570614, 77.57455121517431, 'India', 346, False, 8886197.464145478, 2961151.647999301)
# ('4d85719d7e8ef04d03be21be', 'NMH Tiffin House', 12.954300016820962, 77.5788060159709, 'Near Minerva Circle, VV Puram (Rama Iyengar Rd), Bangalore, Karnātaka, India', 247, False, 8887090.566945955, 2961420.7296396075)
# ('4d29ccc66e27a14317362824', 'Hotel Nandhini', 12.955307313850327, 77.5794984145012, 'No. 114/2, Near Minerva Circle (L.F. Road), Bangalore, Karnātaka, India', 340, False, 8887138.346942313, 2961685.989060371)
# ('4d01ec0e3be26dcb537475e4', 'Mayuri Restaurant', 12.95612026676884, 77.58084503644635, 'J C Road, Bangalore 560002, Karnātaka, India', 252, False, 8887333.77865608, 2961969.19615372)
# ('4f9106e7e4b047933d3bd06c', 'Kamat Minerva', 12.955600874430939, 77.58048282394307, 'Jc Road, India', 315, False, 8887308.115111755, 2961831.960018265)
# ('4b5294ccf964a520ff8227e3', 'Mavalli Tiffin Room (MTR)', 12.955122296207755, 77.58555184054242, '#14 (Lalbagh Rd), Bangalore 560027, Karnātaka, India', 262, False, 8888360.407518657, 2962179.604043238)
# ('4fd42e76e4b0cb311f19d51c', 'nisarga veg', 12.953920364379883, 77.58514404296875, 'India', 327, False, 8888386.741096333, 2961899.7488726866)
# ('5b45bcb4fdb9a7002cac1cfe', 'Naidu Military Hotel', 12.955049, 77.58554, 'Bangalore 560027, Karnātaka, India', 263, False, 8888364.608300162, 2962163.6813675854)
# ...
# Total: 461

# %%
print('List of Italian restaurants')
print('---------------------------')
for r in list(italian_restaurants.values())[:10]:
    print(r)
print('...')
print('Total:', len(italian_restaurants))
# Out:
# List of Italian restaurants
# ---------------------------
# ('534ffaca498e9ea777d34e9b', 'Ottimo', 12.967041213267786, 77.59563043238367, 'ITC Gardenia, Bangalore, Karnātaka, India', 342, True, 8889300.258001408, 2965484.8211480663)
# ('4bc1cd90b492d13a4e74a660', 'Toscano', 12.97198038085137, 77.59606565238312, 'UB City Level 2 Concorde Block (24 Vittal Mallya Road), Bangalore, Karnātaka, India', 276, True, 8888944.322836278, 2966525.8619835787)
# ('524c709211d27c7b392a7897', 'Alba', 12.97254127003947, 77.59459436597112, 'JW Marriott Bengaluru (Vittal Mallya Road), Bangalore, Karnātaka, India', 264, True, 8888601.126964148, 2966510.4179724376)
# ('5050aec7e4b0dd1afe0a1f4e', 'The Tower Kitchen', 12.971671379872115, 77.5963634706781, 'India', 280, True, 8889031.31274633, 2966489.3053250257)
# ('5110cd35e4b0162f3fc169ee', 'Cafe Mangii', 12.971984856069145, 77.59597131547177, 'UB CITY, India', 283, True, 8888925.139084797, 2966518.478977431)
# ('526b900d11d267e76ab188f4', 'Café Mangii', 12.9719497259831, 77.59603332424915, 'UB City (Vittal Mallya Road), Bangalore, Karnātaka, India', 281, True, 8888940.633558093, 2966516.797099394)
# ('4d1302222e5837040bd1e8d1', 'Little Chef', 12.964428442343943, 77.61368011489583, 'Austin Town, Bangalore 560047, Karnātaka, India', 311, True, 8893129.471291458, 2966541.0719509996)
# ('4bebb117b3352d7fefc656d2', "Sunny's", 12.972023446176495, 77.59845399703514, '50, Lavelle Road, Opposite Loom (Vittal Mallya Rd), Bangalore 560001, Karnātaka, India', 223, True, 8889415.99891694, 2966744.540777979)
# ('568fd6a638fababcf49964c9', 'Chianti Ristorante & Wine Bar', 12.97081, 77.600533, "St Mark's Road, 560001, India", 100, True, 8889938.739855658, 2966680.9357327465)
# ('4d80d03f7c956dcb7782e77b', 'Sbarro', 12.991616045479297, 77.57052596076036, 'Mantri Mall, Sampige Rd, Seshadripuram, Bangalore, Karnātaka, India', 181, True, 8882102.841961462, 2968266.3094978086)
# ...
# Total: 14

# %%
print('Restaurants around location')
print('---------------------------')
for i in range(100, 110):
    rs = location_restaurants[i][:8]
    names = ', '.join([r[1] for r in rs])
    print('Restaurants around location {}: {}'.format(i+1, names))
# Out:
# Restaurants around location
# ---------------------------
# Restaurants around location 101: Hotel Fishland, Sukh Sagar GandhiNagar, Chicken County, Kamat Yatrinivas, Sukh Sagar Food Court, navayuga, Kamat Hotel, Talk Of The Town
# Restaurants around location 102: Hotel Fishland, Vasudev Adigas, Adigas Hotel, Sukh Sagar GandhiNagar, Kamat Yatrinivas, New Shanti Sagar, Sukh Sagar Food Court
# Restaurants around location 103: Vasudev Adigas, Adigas Hotel
# Restaurants around location 104: Kaveri Bhavan, Cubbonpet Biriyani Bazaar
# Restaurants around location 105: Bhagini, Rajdhani, Kaveri Bhavan
# Restaurants around location 106: Rajdhani
# Restaurants around location 107: Palate Corner, Konark Kanteerava
# Restaurants around location 108: Kebabs & Kurries, Kudla, EDO, Palate Corner, Ottimo, Legacy Of Punjab, Woody's
# Restaurants around location 109: Kebabs & Kurries, Mahesh Lunch Home, Kudla, EDO, Kazé, Sunheri Restaurant, Aromas of China, Woody's
# Restaurants around location 110: Harima, Mahesh Lunch Home, Kazé, Aromas of China, The Pride Hotel, Beijing Bites, Wok, Casa Piccola

# %%
map_bang = folium.Map(location = [bang_lat,bang_long],zoom_start =12)
folium.Marker([bang_lat,bang_long],popup='Banglore').add_to(map_bang)
for res in restaurants.values():
    lat = res[2]; lon = res[3]
    is_italian = res[6]
    color = 'red' if is_italian else 'blue'
    folium.CircleMarker([lat, lon], radius=3, color=color, fill=True, fill_color=color, fill_opacity=1).add_to(map_bang)
map_bang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
location_restaurants_count = [len(res) for res in location_restaurants]
# location_restaurants_count
df_locations['Restaurants in area'] = location_restaurants_count[0:155]

print('Average number of restaurants in every area with radius=300m:', np.array(location_restaurants_count).mean())

df_locations.head(10)
# Out:
# Average number of restaurants in every area with radius=300m: 3.489010989010989
#                                              Address  ...  Restaurants in area
# 0  Fort High School, Krishna Rajendra Road, Maval...  ...                    1
# 1  Dharmaraya Swamy Temple Ward, South Zone, Beng...  ...                    1
# 2  Dharmaraya Swamy Temple Ward, South Zone, Beng...  ...                    4
# 3  Hindustan Petroleum, Proposed Hudson Cricle - ...  ...                    4
# 4  New car designer, Lalbagh Fort Road, Mavalli, ...  ...                    1
# 5  Lalbagh Botanical Gardens, ಪಾದಚಾರಿ ಮಾರ್ಗ, Mava...  ...                    3
# 6  Lalbagh Botanical Gardens, ಪಾದಚಾರಿ ಮಾರ್ಗ, Mava...  ...                    0
# 7  St. Joseph's School, Cottonpete Main Road, K R...  ...                    1
# 8  Bangalore Medical College Hospitals, ಸುಲ್ತಾನ್ ...  ...                    1
# 9  Srinidhi Sagar, 2, Krishna Rajendra Road, K R ...  ...                    1
#
# [10 rows x 7 columns]

# %%
distances_to_italian_restaurant = []

for area_x, area_y in zip(xs, ys):
    min_distance = 10000
    for res in italian_restaurants.values():
        res_x = res[7]
        res_y = res[8]
        d = calc_xy_distance(area_x, area_y, res_x, res_y)
        if d<min_distance:
            min_distance = d
    distances_to_italian_restaurant.append(min_distance)

df_locations['Distance to Italian restaurant'] = distances_to_italian_restaurant[0:155]

# %%
df_locations.head(10)
# Out:
#                                              Address  ...  Distance to Italian restaurant
# 0  Fort High School, Krishna Rajendra Road, Maval...  ...                     5225.267649
# 1  Dharmaraya Swamy Temple Ward, South Zone, Beng...  ...                     4813.516635
# 2  Dharmaraya Swamy Temple Ward, South Zone, Beng...  ...                     4444.824269
# 3  Hindustan Petroleum, Proposed Hudson Cricle - ...  ...                     4130.736395
# 4  New car designer, Lalbagh Fort Road, Mavalli, ...  ...                     3884.521019
# 5  Lalbagh Botanical Gardens, ಪಾದಚಾರಿ ಮಾರ್ಗ, Mava...  ...                     3719.680623
# 6  Lalbagh Botanical Gardens, ಪಾದಚಾರಿ ಮಾರ್ಗ, Mava...  ...                     3647.265321
# 7  St. Joseph's School, Cottonpete Main Road, K R...  ...                     5597.880918
# 8  Bangalore Medical College Hospitals, ಸುಲ್ತಾನ್ ...  ...                     5111.045994
# 9  Srinidhi Sagar, 2, Krishna Rajendra Road, K R ...  ...                     4650.732366
#
# [10 rows x 8 columns]

# %%
restaurant_latlons = [[res[2], res[3]] for res in restaurants.values()]

italian_latlons = [[res[2], res[3]] for res in italian_restaurants.values()]

# %%
good_latitudes = df_locations['Latitude'].values
good_longitudes = df_locations['Longitude'].values

# %%
print('Average distance to closest Italian restaurant from each area center:', df_locations['Distance to Italian restaurant'].mean())
# Out:
# Average distance to closest Italian restaurant from each area center: 2620.790324034266

# %%
from folium.plugins import HeatMap
from sklearn.cluster import KMeans

number_of_clusters = 15

good_xys = df_locations[['X', 'Y']].values
kmeans = KMeans(n_clusters=number_of_clusters, random_state=0).fit(good_xys)

cluster_centers = [xy_to_langlot(cc[0], cc[1]) for cc in kmeans.cluster_centers_]

map_bang = folium.Map(location= [bang_lat,bang_long], zoom_start=14)
folium.TileLayer('cartodbpositron').add_to(map_bang)
HeatMap(restaurant_latlons).add_to(map_bang)
folium.Circle( [bang_lat,bang_long], radius=2500, color='white', fill=True, fill_opacity=0.4).add_to(map_bang)
folium.Marker( [bang_lat,bang_long]).add_to(map_berlin)
for lon, lat in cluster_centers:
    folium.Circle([lat, lon], radius=500, color='green', fill=True, fill_opacity=0.25).add_to(map_bang) 
for lat, lon in zip(good_latitudes, good_longitudes):
    folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_bang)
#folium.GeoJson(berlin_boroughs, style_function=boroughs_style, name='geojson').add_to(map_berlin)
map_bang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
